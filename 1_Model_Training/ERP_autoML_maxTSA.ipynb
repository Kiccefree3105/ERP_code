# %%
#!conda --version
#!pip install flaml[automl]
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from flaml import AutoML
import sklearn
from sklearn.ensemble import RandomForestRegressor as RF
import pickle
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from flaml.automl.data import get_output_from_log

print("FLAML version: {}".format(AutoML.__version__))
print("Numpy version: {}".format(np.__version__))
print("Pandas version: {}".format(pd.__version__))
print("SKLearn version: {}".format(sklearn.__version__))
print("Seaborn version: {}".format(sns.__version__))
# Out:
# FLAML version: 2.3.5
# Numpy version: 1.26.4
# Pandas version: 2.2.2
# SKLearn version: 1.4.2
# Seaborn version: 0.13.2

# %%
# The data catalogue is stored as a CSV file. Here we read it with pandas.

data_path1 = 'D:/A_sem2/ERP/Simulation/new_lhs/lhs_exps.csv' # Change this to the path of the data file on your system
data_path2 = 'D:/A_sem2/ERP/Code/TSA_max_min_mean.xlsx' # Change this to the path of the data file on your system
# Load the data
df1 = pd.read_csv(data_path1, index_col=0, parse_dates=True)
df1 = df1.drop(columns=['ALB_ROOF_DIF', 'ALB_IMPROAD_DIF', 'ALB_PERROAD_DIF', 'ALB_WALL_DIF','WIND_HGT_CANYON'])
df2 = pd.read_excel(data_path2, parse_dates=True)
df1 = pd.concat([df1, df2.iloc[:, 0]], axis=1) # 将要df2中的第一个变量合并到df1中（放到最后一列）
display(df1.head(10))
#display(df2.head(10))
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14276\780021997.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1 = pd.read_csv(data_path1, index_col=0, parse_dates=True)
#    ALB_ROOF_DIR   EM_ROOF  ALB_IMPROAD_DIR  EM_IMPROAD  ALB_PERROAD_DIR  \
# 0      0.867109  0.990241         0.151921    0.897831         0.103656
# 1      0.689149  0.837570         0.183997    0.856856         0.129165
# 2      0.440487  0.904625         0.216487    0.883614         0.202678
# 3      0.996312  0.805200         0.193108    0.979353         0.201636
# 4      0.074822  0.997615         0.124448    0.820825         0.235898
# 5      0.591587  0.953099         0.183550    0.877301         0.250634
# 6      0.326387  0.821426         0.237143    0.964384         0.089455
# 7      0.520424  0.863322         0.178181    0.759688         0.117607
# 8      0.067640  0.991442         0.081745    0.760505         0.208679
# 9      0.640687  0.912066         0.133602    0.970853         0.087581
#
#    EM_PERROAD  ALB_WALL_DIR   EM_WALL    HT_ROOF  CANYON_HWR  WTLUNIT_ROOF  \
# 0    0.937855      0.629264  0.993075  20.309085    1.124637      0.042698
# 1    0.764162      0.795071  0.957548  26.415594    1.685905      0.788026
# 2    0.760849      0.095133  0.791472  23.112687    3.775621      0.214968
# 3    0.955750      0.321593  0.983677   8.862520    0.005116      0.400565
# 4    0.891563      0.740665  0.978814  34.097124    1.006281      0.105618
# 5    0.927182      0.790999  0.798064   7.931632    1.078923      0.664799
# 6    0.781013      0.196795  0.912113  20.101002    2.762589      0.813611
# 7    0.769108      0.379394  0.765241  15.565857    1.885627      0.626730
# 8    0.980417      0.804406  0.966493   2.886291    1.088612      0.291988
# 9    0.805194      0.570245  0.827483  33.144693    2.987144      0.766867
#
#    WTROAD_PERV  TSA_peak_max_mean
# 0     0.355400         307.867767
# 1     0.364434         307.990570
# 2     0.589368         306.849182
# 3     0.348086         308.557922
# 4     0.840065         306.555237
# 5     0.645066         307.946350
# 6     0.248532         310.477478
# 7     0.033196         309.409668
# 8     0.092915         310.416687
# 9     0.946950         307.759155

# %%
# 绘制13个变量的概率密度图

# 你需要绘制的13个变量名列表（对应df1列名）
var_names = [
    'ALB_ROOF_DIR',
    'EM_ROOF',
    'ALB_IMPROAD_DIR',
    'EM_IMPROAD',
    'ALB_PERROAD_DIR',
    'EM_PERROAD',
    'ALB_WALL_DIR',
    'EM_WALL',
    # 'WIND_HGT_CANYON',
    'HT_ROOF',
    'CANYON_HWR',
    'WTLUNIT_ROOF',
    'WTROAD_PERV'
]

# 创建画布，4行4列，留出1个空白子图
fig, axes = plt.subplots(4, 4, figsize=(20, 15))
axes = axes.flatten()

for i, ax in enumerate(axes):
    if i < len(var_names):
        data = df1[var_names[i]].dropna()  # 如果有NaN，去掉
        sns.histplot(data, kde=True, ax=ax, color='b', stat='density', bins=30)
        ax.set_title(var_names[i])
    else:
        ax.axis('off')  # 多余空白子图隐藏

plt.tight_layout()
plt.show()

# %%
display(df1.describe().T)
# Out:
#                       count        mean       std         min         25%  \
# ALB_ROOF_DIR       100000.0    0.520180  0.277026    0.040366    0.280275
# EM_ROOF            100000.0    0.877924  0.070481    0.755849    0.816887
# ALB_IMPROAD_DIR    100000.0    0.191169  0.071391    0.067518    0.129344
# EM_IMPROAD         100000.0    0.871614  0.074124    0.743230    0.807422
# ALB_PERROAD_DIR    100000.0    0.160972  0.054188    0.067116    0.114044
# EM_PERROAD         100000.0    0.879705  0.069453    0.759411    0.819558
# ALB_WALL_DIR       100000.0    0.446000  0.220549    0.064002    0.255000
# EM_WALL            100000.0    0.877924  0.070481    0.755850    0.816886
# HT_ROOF            100000.0   19.303164  9.913056    2.133453   10.718386
# CANYON_HWR         100000.0    2.168296  1.251635    0.000445    1.084359
# WTLUNIT_ROOF       100000.0    0.448738  0.258880    0.000354    0.224546
# WTROAD_PERV        100000.0    0.511735  0.281901    0.023479    0.267603
# TSA_peak_max_mean  100000.0  307.732927  1.791638  300.624695  306.796013
#
#                           50%         75%         max
# ALB_ROOF_DIR         0.520180    0.760085    0.999993
# EM_ROOF              0.877924    0.938961    1.000000
# ALB_IMPROAD_DIR      0.191168    0.252994    0.314819
# EM_IMPROAD           0.871614    0.935807    0.999998
# ALB_PERROAD_DIR      0.160971    0.207900    0.254826
# EM_PERROAD           0.879705    0.939851    0.999999
# ALB_WALL_DIR         0.446003    0.636997    0.827997
# EM_WALL              0.877924    0.938962    0.999998
# HT_ROOF             19.303182   27.888055   36.472930
# CANYON_HWR           2.168293    3.252235    4.336177
# WTLUNIT_ROOF         0.448737    0.672934    0.897125
# WTROAD_PERV          0.511735    0.755861    0.999994
# TSA_peak_max_mean  307.903030  308.810188  340.600525

# %%
train_num = int(0.8 * len(df1)) # 计算出数据集中前80%的数量，作为训练集的样本数量
train, test = df1.iloc[:train_num], df1.iloc[train_num:] # 使用iloc按行索引进行切片，前80%赋给train，后20%赋给test
train
# Out:
#        ALB_ROOF_DIR   EM_ROOF  ALB_IMPROAD_DIR  EM_IMPROAD  ALB_PERROAD_DIR  \
# 0          0.867109  0.990241         0.151921    0.897831         0.103656
# 1          0.689149  0.837570         0.183997    0.856856         0.129165
# 2          0.440487  0.904625         0.216487    0.883614         0.202678
# 3          0.996312  0.805200         0.193108    0.979353         0.201636
# 4          0.074822  0.997615         0.124448    0.820825         0.235898
# ...             ...       ...              ...         ...              ...
# 79995      0.357790  0.886958         0.300047    0.851810         0.215798
# 79996      0.922056  0.777644         0.141380    0.745530         0.232554
# 79997      0.325904  0.960300         0.288180    0.750185         0.162091
# 79998      0.417894  0.860011         0.109574    0.866886         0.140436
# 79999      0.876836  0.823584         0.125870    0.881727         0.067936
#
#        EM_PERROAD  ALB_WALL_DIR   EM_WALL    HT_ROOF  CANYON_HWR  \
# 0        0.937855      0.629264  0.993075  20.309085    1.124637
# 1        0.764162      0.795071  0.957548  26.415594    1.685905
# 2        0.760849      0.095133  0.791472  23.112687    3.775621
# 3        0.955750      0.321593  0.983677   8.862520    0.005116
# 4        0.891563      0.740665  0.978814  34.097124    1.006281
# ...           ...           ...       ...        ...         ...
# 79995    0.819100      0.266898  0.941220  21.132038    2.499865
# 79996    0.780078      0.128955  0.783014  17.670039    0.021876
# 79997    0.942221      0.644823  0.950538  28.071574    3.812748
# 79998    0.931690      0.516862  0.891222  26.630194    3.292091
# 79999    0.806731      0.195441  0.866802  13.769582    0.496146
#
#        WTLUNIT_ROOF  WTROAD_PERV  TSA_peak_max_mean
# 0          0.042698     0.355400         307.867767
# 1          0.788026     0.364434         307.990570
# 2          0.214968     0.589368         306.849182
# 3          0.400565     0.348086         308.557922
# 4          0.105618     0.840065         306.555237
# ...             ...          ...                ...
# 79995      0.190244     0.775949         307.419861
# 79996      0.609921     0.195292         308.103882
# 79997      0.018528     0.733491         303.551422
# 79998      0.700903     0.477045         309.163635
# 79999      0.144290     0.597815         307.599060
#
# [80000 rows x 13 columns]

# %%
sns.histplot(data=df1, x='TSA_peak_max_mean', bins=30, kde=False, stat='density')
plt.show()

# %%
# =============exploratory data analysis================
# =============trainning data================
display(train.describe().T)
display(train.info())

# =============test data================
display(test.describe().T)
display(test.info())
# Out:
#                      count        mean       std         min         25%  \
# ALB_ROOF_DIR       80000.0    0.519945  0.276894    0.040366    0.280857
# EM_ROOF            80000.0    0.877889  0.070376    0.755849    0.816921
# ALB_IMPROAD_DIR    80000.0    0.191142  0.071295    0.067518    0.129604
# EM_IMPROAD         80000.0    0.871583  0.074113    0.743230    0.807529
# ALB_PERROAD_DIR    80000.0    0.160987  0.054157    0.067116    0.114136
# EM_PERROAD         80000.0    0.879739  0.069426    0.759411    0.819630
# ALB_WALL_DIR       80000.0    0.446270  0.220410    0.064002    0.255797
# EM_WALL            80000.0    0.877902  0.070501    0.755851    0.816882
# HT_ROOF            80000.0   19.310484  9.923235    2.133453   10.683063
# CANYON_HWR         80000.0    2.166486  1.252202    0.000445    1.083184
# WTLUNIT_ROOF       80000.0    0.448728  0.258771    0.000373    0.224619
# WTROAD_PERV        80000.0    0.511045  0.282193    0.023482    0.266551
# TSA_peak_max_mean  80000.0  307.734491  1.794260  300.624695  306.796593
#
#                           50%         75%         max
# ALB_ROOF_DIR         0.519916    0.759878    0.999993
# EM_ROOF              0.877983    0.938615    1.000000
# ALB_IMPROAD_DIR      0.191013    0.252829    0.314819
# EM_IMPROAD           0.871668    0.935728    0.999995
# ALB_PERROAD_DIR      0.160991    0.207863    0.254826
# EM_PERROAD           0.879701    0.939910    0.999999
# ALB_WALL_DIR         0.446541    0.637101    0.827997
# EM_WALL              0.877936    0.938908    0.999998
# HT_ROOF             19.313849   27.916400   36.472930
# CANYON_HWR           2.165793    3.251737    4.336177
# WTLUNIT_ROOF         0.448493    0.673172    0.897125
# WTROAD_PERV          0.509871    0.755832    0.999994
# TSA_peak_max_mean  307.905273  308.813797  340.600525
# <class 'pandas.core.frame.DataFrame'>
# Index: 80000 entries, 0 to 79999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ALB_ROOF_DIR       80000 non-null  float64
#  1   EM_ROOF            80000 non-null  float64
#  2   ALB_IMPROAD_DIR    80000 non-null  float64
#  3   EM_IMPROAD         80000 non-null  float64
#  4   ALB_PERROAD_DIR    80000 non-null  float64
#  5   EM_PERROAD         80000 non-null  float64
#  6   ALB_WALL_DIR       80000 non-null  float64
#  7   EM_WALL            80000 non-null  float64
#  8   HT_ROOF            80000 non-null  float64
#  9   CANYON_HWR         80000 non-null  float64
#  10  WTLUNIT_ROOF       80000 non-null  float64
#  11  WTROAD_PERV        80000 non-null  float64
#  12  TSA_peak_max_mean  80000 non-null  float64
# dtypes: float64(13)
# memory usage: 8.5 MB
# None
#                      count        mean       std         min         25%  \
# ALB_ROOF_DIR       20000.0    0.521122  0.277554    0.040422    0.278029
# EM_ROOF            20000.0    0.878064  0.070901    0.755865    0.816783
# ALB_IMPROAD_DIR    20000.0    0.191274  0.071775    0.067528    0.128336
# EM_IMPROAD         20000.0    0.871737  0.074169    0.743231    0.807077
# ALB_PERROAD_DIR    20000.0    0.160913  0.054313    0.067119    0.113714
# EM_PERROAD         20000.0    0.879569  0.069560    0.759501    0.819210
# ALB_WALL_DIR       20000.0    0.444920  0.221106    0.064030    0.251881
# EM_WALL            20000.0    0.878013  0.070402    0.755850    0.816948
# HT_ROOF            20000.0   19.273883  9.872430    2.136065   10.851467
# CANYON_HWR         20000.0    2.175539  1.249368    0.000652    1.091539
# WTLUNIT_ROOF       20000.0    0.448777  0.259319    0.000354    0.224096
# WTROAD_PERV        20000.0    0.514498  0.280722    0.023479    0.272180
# TSA_peak_max_mean  20000.0  307.726670  1.781143  301.029938  306.793968
#
#                           50%         75%         max
# ALB_ROOF_DIR         0.521229    0.761007    0.999966
# EM_ROOF              0.877609    0.940517    0.999989
# ALB_IMPROAD_DIR      0.191834    0.253563    0.314806
# EM_IMPROAD           0.871442    0.936075    0.999998
# ALB_PERROAD_DIR      0.160861    0.208043    0.254817
# EM_PERROAD           0.879721    0.939594    0.999995
# ALB_WALL_DIR         0.444128    0.636648    0.827920
# EM_WALL              0.877888    0.939189    0.999976
# HT_ROOF             19.257810   27.800664   36.470165
# CANYON_HWR           2.177988    3.255210    4.335952
# WTLUNIT_ROOF         0.449577    0.672046    0.897111
# WTROAD_PERV          0.519289    0.755986    0.999981
# TSA_peak_max_mean  307.893127  308.798347  326.560211
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, 80000 to 99999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ALB_ROOF_DIR       20000 non-null  float64
#  1   EM_ROOF            20000 non-null  float64
#  2   ALB_IMPROAD_DIR    20000 non-null  float64
#  3   EM_IMPROAD         20000 non-null  float64
#  4   ALB_PERROAD_DIR    20000 non-null  float64
#  5   EM_PERROAD         20000 non-null  float64
#  6   ALB_WALL_DIR       20000 non-null  float64
#  7   EM_WALL            20000 non-null  float64
#  8   HT_ROOF            20000 non-null  float64
#  9   CANYON_HWR         20000 non-null  float64
#  10  WTLUNIT_ROOF       20000 non-null  float64
#  11  WTROAD_PERV        20000 non-null  float64
#  12  TSA_peak_max_mean  20000 non-null  float64
# dtypes: float64(13)
# memory usage: 2.1 MB
# None

# %% [markdown]
# ### Define the features and target variable

# %%
feature_ls = df1.columns.tolist()
feature_ls.remove('TSA_peak_max_mean')
print('The features are:', feature_ls)

label = 'TSA_peak_max_mean'
print('The label is:', label)
# Out:
# The features are: ['ALB_ROOF_DIR', 'EM_ROOF', 'ALB_IMPROAD_DIR', 'EM_IMPROAD', 'ALB_PERROAD_DIR', 'EM_PERROAD', 'ALB_WALL_DIR', 'EM_WALL', 'HT_ROOF', 'CANYON_HWR', 'WTLUNIT_ROOF', 'WTROAD_PERV']
# The label is: TSA_peak_max_mean

# %% [markdown]
# ### Train the model

# %%
# ====== train model ======
time_budget = 500  # total running time in seconds

# specify the estimator list
estimator_list = ['lgbm', 'rf', 'xgboost']

# create the AutoML object
automl = AutoML()

# specify the automl settings
automl_settings = {
    "time_budget": time_budget,  # in seconds
    "estimator_list":estimator_list, # estimators
    "metric": 'rmse', # metric参数是用来指定模型评估和搜索时优化的目标指标。AutoML将基于RMSE进行模型选择和超参搜索
    "task": 'regression', # 指定进行回归任务。另外还有分类任务等
    "log_file_name": "log.log"
}

# fit the model
automl.fit(train[feature_ls], train[label], **automl_settings) #,max_iter=2
print(automl.model.estimator)
# Out:
# [flaml.automl.logger: 08-09 13:08:20] {1752} INFO - task = regression
# [flaml.automl.logger: 08-09 13:08:20] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 08-09 13:08:20] {1862} INFO - Minimizing error metric: rmse
# [flaml.automl.logger: 08-09 13:08:20] {1979} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost']
# [flaml.automl.logger: 08-09 13:08:20] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:20] {2417} INFO - Estimated sufficient time budget=3631s. Estimated necessary time budget=4s.
# [flaml.automl.logger: 08-09 13:08:20] {2466} INFO -  at 0.6s,	estimator lgbm's best error=1.5456,	best estimator lgbm's best error=1.5456
# [flaml.automl.logger: 08-09 13:08:20] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:20] {2466} INFO -  at 1.0s,	estimator lgbm's best error=1.5456,	best estimator lgbm's best error=1.5456
# [flaml.automl.logger: 08-09 13:08:20] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:21] {2466} INFO -  at 1.4s,	estimator lgbm's best error=1.2798,	best estimator lgbm's best error=1.2798
# [flaml.automl.logger: 08-09 13:08:21] {2282} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:21] {2466} INFO -  at 1.7s,	estimator xgboost's best error=1.5453,	best estimator lgbm's best error=1.2798
# [flaml.automl.logger: 08-09 13:08:21] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:22] {2466} INFO -  at 2.1s,	estimator lgbm's best error=0.7939,	best estimator lgbm's best error=0.7939
# [flaml.automl.logger: 08-09 13:08:22] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:22] {2466} INFO -  at 2.5s,	estimator lgbm's best error=0.7939,	best estimator lgbm's best error=0.7939
# [flaml.automl.logger: 08-09 13:08:22] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:22] {2466} INFO -  at 2.9s,	estimator lgbm's best error=0.7235,	best estimator lgbm's best error=0.7235
# [flaml.automl.logger: 08-09 13:08:22] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:23] {2466} INFO -  at 3.3s,	estimator lgbm's best error=0.7235,	best estimator lgbm's best error=0.7235
# [flaml.automl.logger: 08-09 13:08:23] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:23] {2466} INFO -  at 3.7s,	estimator lgbm's best error=0.7235,	best estimator lgbm's best error=0.7235
# [flaml.automl.logger: 08-09 13:08:23] {2282} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:23] {2466} INFO -  at 4.0s,	estimator xgboost's best error=1.5453,	best estimator lgbm's best error=0.7235
# [flaml.automl.logger: 08-09 13:08:23] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:24] {2466} INFO -  at 4.5s,	estimator lgbm's best error=0.5626,	best estimator lgbm's best error=0.5626
# [flaml.automl.logger: 08-09 13:08:24] {2282} INFO - iteration 11, current learner rf
# [flaml.automl.logger: 08-09 13:08:26] {2466} INFO -  at 6.2s,	estimator rf's best error=1.3276,	best estimator lgbm's best error=0.5626
# [flaml.automl.logger: 08-09 13:08:26] {2282} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:26] {2466} INFO -  at 6.5s,	estimator xgboost's best error=1.2930,	best estimator lgbm's best error=0.5626
# [flaml.automl.logger: 08-09 13:08:26] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:26] {2466} INFO -  at 6.9s,	estimator lgbm's best error=0.5626,	best estimator lgbm's best error=0.5626
# [flaml.automl.logger: 08-09 13:08:26] {2282} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 08-09 13:08:29] {2466} INFO -  at 9.8s,	estimator rf's best error=0.9198,	best estimator lgbm's best error=0.5626
# [flaml.automl.logger: 08-09 13:08:29] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:31] {2466} INFO -  at 11.2s,	estimator lgbm's best error=0.3482,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:31] {2282} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:31] {2466} INFO -  at 11.5s,	estimator xgboost's best error=1.0254,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:31] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:33] {2466} INFO -  at 13.8s,	estimator lgbm's best error=0.3482,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:33] {2282} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:34] {2466} INFO -  at 14.1s,	estimator xgboost's best error=1.0254,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:34] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:35] {2466} INFO -  at 15.3s,	estimator lgbm's best error=0.3482,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:35] {2282} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 08-09 13:08:36] {2466} INFO -  at 17.0s,	estimator rf's best error=0.9198,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:36] {2282} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:38] {2466} INFO -  at 18.4s,	estimator lgbm's best error=0.3482,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:38] {2282} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:40] {2466} INFO -  at 20.8s,	estimator lgbm's best error=0.3482,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:40] {2282} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:41] {2466} INFO -  at 21.1s,	estimator xgboost's best error=1.0254,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:41] {2282} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:41] {2466} INFO -  at 21.4s,	estimator xgboost's best error=0.8034,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:41] {2282} INFO - iteration 25, current learner rf
# [flaml.automl.logger: 08-09 13:08:45] {2466} INFO -  at 25.1s,	estimator rf's best error=0.6775,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:45] {2282} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:45] {2466} INFO -  at 25.5s,	estimator xgboost's best error=0.7194,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:45] {2282} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:45] {2466} INFO -  at 25.9s,	estimator xgboost's best error=0.7043,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:45] {2282} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:46] {2466} INFO -  at 26.4s,	estimator xgboost's best error=0.5118,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:46] {2282} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:48] {2466} INFO -  at 29.0s,	estimator lgbm's best error=0.3482,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:48] {2282} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:50] {2466} INFO -  at 30.1s,	estimator lgbm's best error=0.3482,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:50] {2282} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:50] {2466} INFO -  at 30.5s,	estimator xgboost's best error=0.5118,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:50] {2282} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:50] {2466} INFO -  at 30.9s,	estimator xgboost's best error=0.5118,	best estimator lgbm's best error=0.3482
# [flaml.automl.logger: 08-09 13:08:50] {2282} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:54] {2466} INFO -  at 35.0s,	estimator lgbm's best error=0.2352,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:08:54] {2282} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:55] {2466} INFO -  at 35.7s,	estimator xgboost's best error=0.4094,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:08:55] {2282} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:56] {2466} INFO -  at 36.4s,	estimator xgboost's best error=0.4094,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:08:56] {2282} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:57] {2466} INFO -  at 37.5s,	estimator xgboost's best error=0.4094,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:08:57] {2282} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 08-09 13:08:57] {2466} INFO -  at 37.9s,	estimator xgboost's best error=0.4094,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:08:57] {2282} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 08-09 13:08:59] {2466} INFO -  at 39.4s,	estimator lgbm's best error=0.2352,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:08:59] {2282} INFO - iteration 39, current learner xgboost
# [flaml.automl.logger: 08-09 13:09:00] {2466} INFO -  at 40.7s,	estimator xgboost's best error=0.4078,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:09:00] {2282} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 08-09 13:09:05] {2466} INFO -  at 45.7s,	estimator rf's best error=0.4845,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:09:05] {2282} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 08-09 13:09:06] {2466} INFO -  at 47.0s,	estimator lgbm's best error=0.2352,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:09:06] {2282} INFO - iteration 42, current learner rf
# [flaml.automl.logger: 08-09 13:09:11] {2466} INFO -  at 51.9s,	estimator rf's best error=0.4845,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:09:11] {2282} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 08-09 13:09:12] {2466} INFO -  at 52.5s,	estimator xgboost's best error=0.4078,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:09:12] {2282} INFO - iteration 44, current learner rf
# [flaml.automl.logger: 08-09 13:09:20] {2466} INFO -  at 60.1s,	estimator rf's best error=0.3930,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:09:20] {2282} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 08-09 13:09:30] {2466} INFO -  at 70.3s,	estimator lgbm's best error=0.2352,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:09:30] {2282} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 08-09 13:09:35] {2466} INFO -  at 75.7s,	estimator rf's best error=0.3930,	best estimator lgbm's best error=0.2352
# [flaml.automl.logger: 08-09 13:09:35] {2282} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 08-09 13:09:39] {2466} INFO -  at 79.5s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:09:39] {2282} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 08-09 13:09:42] {2466} INFO -  at 82.3s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:09:42] {2282} INFO - iteration 49, current learner rf
# [flaml.automl.logger: 08-09 13:09:47] {2466} INFO -  at 87.5s,	estimator rf's best error=0.3437,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:09:47] {2282} INFO - iteration 50, current learner lgbm
# [flaml.automl.logger: 08-09 13:09:50] {2466} INFO -  at 90.6s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:09:50] {2282} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 08-09 13:09:56] {2466} INFO -  at 96.6s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:09:56] {2282} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 08-09 13:10:08] {2466} INFO -  at 108.3s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:08] {2282} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 08-09 13:10:10] {2466} INFO -  at 110.2s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:10] {2282} INFO - iteration 54, current learner rf
# [flaml.automl.logger: 08-09 13:10:13] {2466} INFO -  at 113.9s,	estimator rf's best error=0.3437,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:13] {2282} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 08-09 13:10:21] {2466} INFO -  at 121.8s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:21] {2282} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 08-09 13:10:23] {2466} INFO -  at 123.5s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:23] {2282} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 08-09 13:10:24] {2466} INFO -  at 124.9s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:24] {2282} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 08-09 13:10:43] {2466} INFO -  at 143.7s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:43] {2282} INFO - iteration 59, current learner rf
# [flaml.automl.logger: 08-09 13:10:52] {2466} INFO -  at 152.3s,	estimator rf's best error=0.3437,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:52] {2282} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 08-09 13:10:55] {2466} INFO -  at 155.2s,	estimator lgbm's best error=0.2315,	best estimator lgbm's best error=0.2315
# [flaml.automl.logger: 08-09 13:10:55] {2282} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 08-09 13:11:01] {2466} INFO -  at 161.3s,	estimator lgbm's best error=0.2248,	best estimator lgbm's best error=0.2248
# [flaml.automl.logger: 08-09 13:11:01] {2282} INFO - iteration 62, current learner rf
# [flaml.automl.logger: 08-09 13:11:12] {2466} INFO -  at 172.6s,	estimator rf's best error=0.3437,	best estimator lgbm's best error=0.2248
# [flaml.automl.logger: 08-09 13:11:12] {2282} INFO - iteration 63, current learner lgbm
# [flaml.automl.logger: 08-09 13:11:17] {2466} INFO -  at 177.5s,	estimator lgbm's best error=0.2248,	best estimator lgbm's best error=0.2248
# [flaml.automl.logger: 08-09 13:11:17] {2282} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 08-09 13:11:23] {2466} INFO -  at 183.2s,	estimator lgbm's best error=0.2248,	best estimator lgbm's best error=0.2248
# [flaml.automl.logger: 08-09 13:11:23] {2282} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 08-09 13:11:28] {2466} INFO -  at 188.9s,	estimator rf's best error=0.3437,	best estimator lgbm's best error=0.2248
# [flaml.automl.logger: 08-09 13:11:28] {2282} INFO - iteration 66, current learner lgbm
# [flaml.automl.logger: 08-09 13:11:53] {2466} INFO -  at 213.6s,	estimator lgbm's best error=0.2248,	best estimator lgbm's best error=0.2248
# [flaml.automl.logger: 08-09 13:11:53] {2282} INFO - iteration 67, current learner lgbm
# [flaml.automl.logger: 08-09 13:11:54] {2466} INFO -  at 214.8s,	estimator lgbm's best error=0.2248,	best estimator lgbm's best error=0.2248
# [flaml.automl.logger: 08-09 13:11:54] {2282} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 08-09 13:12:04] {2466} INFO -  at 224.3s,	estimator lgbm's best error=0.2104,	best estimator lgbm's best error=0.2104
# [flaml.automl.logger: 08-09 13:12:04] {2282} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 08-09 13:12:08] {2466} INFO -  at 228.3s,	estimator lgbm's best error=0.2104,	best estimator lgbm's best error=0.2104
# [flaml.automl.logger: 08-09 13:12:08] {2282} INFO - iteration 70, current learner lgbm
# [flaml.automl.logger: 08-09 13:13:25] {2466} INFO -  at 306.0s,	estimator lgbm's best error=0.2020,	best estimator lgbm's best error=0.2020
# [flaml.automl.logger: 08-09 13:13:25] {2282} INFO - iteration 71, current learner rf
# [flaml.automl.logger: 08-09 13:13:38] {2466} INFO -  at 318.2s,	estimator rf's best error=0.2967,	best estimator lgbm's best error=0.2020
# [flaml.automl.logger: 08-09 13:13:38] {2282} INFO - iteration 72, current learner lgbm
# [flaml.automl.logger: 08-09 13:13:46] {2466} INFO -  at 326.2s,	estimator lgbm's best error=0.2020,	best estimator lgbm's best error=0.2020
# [flaml.automl.logger: 08-09 13:13:46] {2282} INFO - iteration 73, current learner rf
# [flaml.automl.logger: 08-09 13:13:54] {2466} INFO -  at 334.1s,	estimator rf's best error=0.2967,	best estimator lgbm's best error=0.2020
# [flaml.automl.logger: 08-09 13:13:54] {2282} INFO - iteration 74, current learner lgbm
# [flaml.automl.logger: 08-09 13:14:02] {2466} INFO -  at 342.2s,	estimator lgbm's best error=0.2020,	best estimator lgbm's best error=0.2020
# [flaml.automl.logger: 08-09 13:14:02] {2282} INFO - iteration 75, current learner lgbm
# [flaml.automl.logger: 08-09 13:16:52] {2466} INFO -  at 512.6s,	estimator lgbm's best error=0.1949,	best estimator lgbm's best error=0.1949
# [flaml.automl.logger: 08-09 13:18:25] {2724} INFO - retrain lgbm for 93.3s
# [flaml.automl.logger: 08-09 13:18:25] {2727} INFO - retrained model: LGBMRegressor(colsample_bytree=0.793282520584286,
#               learning_rate=0.03738170215583523, max_bin=1023,
#               min_child_samples=9, n_estimators=14142, n_jobs=-1,
#               num_leaves=109, reg_alpha=0.028508654862734066,
#               reg_lambda=0.018825817301132843, verbose=-1)
# [flaml.automl.logger: 08-09 13:18:25] {2009} INFO - fit succeeded
# [flaml.automl.logger: 08-09 13:18:25] {2010} INFO - Time taken to find the best model: 512.6307168006897
# LGBMRegressor(colsample_bytree=0.793282520584286,
#               learning_rate=0.03738170215583523, max_bin=1023,
#               min_child_samples=9, n_estimators=14142, n_jobs=-1,
#               num_leaves=109, reg_alpha=0.028508654862734066,
#               reg_lambda=0.018825817301132843, verbose=-1)

# %%
print("Best estimator:", automl.model.estimator)
print("Best validation RMSE:", automl.best_loss)
# Out:
# Best estimator: LGBMRegressor(colsample_bytree=0.793282520584286,
#               learning_rate=0.03738170215583523, max_bin=1023,
#               min_child_samples=9, n_estimators=14142, n_jobs=-1,
#               num_leaves=109, reg_alpha=0.028508654862734066,
#               reg_lambda=0.018825817301132843, verbose=-1)
# Best validation RMSE: 0.19485656730981454

# %% [markdown]
# ### Evaluate the final model performance

# %%
print('Trainning data')
y_train = train[label]
y_pred_train = automl.predict(train[feature_ls])

rmse = mean_squared_error(y_train, y_pred_train, squared=False)# 使用train里面的数据计算得到的rmse
r2 = r2_score(y_train, y_pred_train)
mae = mean_absolute_error(y_train, y_pred_train)
print('RMSE:', rmse)
print('R2:', r2)
print('MAE:', mae)
# Out:
# Trainning data
# RMSE: 0.0022077576309706437
# R2: 0.999998485960336
# MAE: 0.001625668413361978
# d:\python_Anaconda_install\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# ====== plot the residual ======
residual = train[label] - y_pred_train
plt.figure(figsize=(10, 5))
sns.histplot(residual, kde=True)
plt.ylabel('Frequency')
plt.xlabel('Residual [K])')
plt.title('Residual distribution')
plt.show()

# %%
# save the model
with open('ERP_automl_model_TSAmax.pkl', 'wb') as f:
    pickle.dump(automl, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Check the logs

# %%
print(automl.best_estimator)

print(automl.best_config)

print(automl.best_config_train_time)

print(automl.best_iteration)

print(automl.best_loss) # 这里用的是RMSE（前面设定的metrics），这里用的是test里的数据计算的RMSE

print(automl.time_to_find_best_model)

print(automl.config_history)
# Out:
# lgbm
# {'n_estimators': 14142, 'num_leaves': 109, 'min_child_samples': 9, 'learning_rate': 0.03738170215583523, 'log_max_bin': 10, 'colsample_bytree': 0.793282520584286, 'reg_alpha': 0.028508654862734066, 'reg_lambda': 0.018825817301132843}
# 93.27827858924866
# 75
# 0.19485656730981454
# 512.6307168006897
# {0: ('lgbm', {'n_estimators': 4, 'num_leaves': 4, 'min_child_samples': 20, 'learning_rate': 0.09999999999999995, 'log_max_bin': 8, 'colsample_bytree': 1.0, 'reg_alpha': 0.0009765625, 'reg_lambda': 1.0}, 0.6071858406066895), 2: ('lgbm', {'n_estimators': 4, 'num_leaves': 4, 'min_child_samples': 12, 'learning_rate': 0.26770501231052046, 'log_max_bin': 7, 'colsample_bytree': 1.0, 'reg_alpha': 0.001348364934537134, 'reg_lambda': 1.4442580148221913}, 1.3773672580718994), 4: ('lgbm', {'n_estimators': 12, 'num_leaves': 4, 'min_child_samples': 9, 'learning_rate': 0.7260594590615893, 'log_max_bin': 9, 'colsample_bytree': 0.9285002286474459, 'reg_alpha': 0.0036840681931986645, 'reg_lambda': 0.7532480505730402}, 2.1153724193573), 6: ('lgbm', {'n_estimators': 14, 'num_leaves': 5, 'min_child_samples': 5, 'learning_rate': 0.7590459488450945, 'log_max_bin': 8, 'colsample_bytree': 0.8304072431299575, 'reg_alpha': 0.001951378031519758, 'reg_lambda': 0.04792552866398477}, 2.8765687942504883), 10: ('lgbm', {'n_estimators': 53, 'num_leaves': 4, 'min_child_samples': 4, 'learning_rate': 0.41929025492645006, 'log_max_bin': 8, 'colsample_bytree': 0.7610534336273627, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.009280655005879927}, 4.509388208389282), 15: ('lgbm', {'n_estimators': 189, 'num_leaves': 20, 'min_child_samples': 3, 'learning_rate': 0.17402065726724145, 'log_max_bin': 8, 'colsample_bytree': 0.6649148062238498, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.006761362450996487}, 11.229356288909912), 33: ('lgbm', {'n_estimators': 109, 'num_leaves': 84, 'min_child_samples': 2, 'learning_rate': 0.1530612501227463, 'log_max_bin': 10, 'colsample_bytree': 0.7463308378914483, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.012698515198279517}, 34.97319316864014), 47: ('lgbm', {'n_estimators': 218, 'num_leaves': 39, 'min_child_samples': 2, 'learning_rate': 0.18908812295671118, 'log_max_bin': 10, 'colsample_bytree': 0.7965188503204359, 'reg_alpha': 0.004577823970660193, 'reg_lambda': 0.02722880765786953}, 79.52716279029846), 61: ('lgbm', {'n_estimators': 558, 'num_leaves': 17, 'min_child_samples': 4, 'learning_rate': 0.1591234985903699, 'log_max_bin': 10, 'colsample_bytree': 0.8550732733223378, 'reg_alpha': 0.036114468962103394, 'reg_lambda': 0.028209651407471815}, 161.33840680122375), 68: ('lgbm', {'n_estimators': 1228, 'num_leaves': 15, 'min_child_samples': 7, 'learning_rate': 0.08108481044463384, 'log_max_bin': 10, 'colsample_bytree': 0.838019535354181, 'reg_alpha': 0.003941416412231428, 'reg_lambda': 0.10554687066068354}, 224.26029896736145), 70: ('lgbm', {'n_estimators': 3105, 'num_leaves': 81, 'min_child_samples': 7, 'learning_rate': 0.09923336893317476, 'log_max_bin': 10, 'colsample_bytree': 0.7750396473588606, 'reg_alpha': 0.014094603319861362, 'reg_lambda': 0.026152243630780125}, 306.0122208595276), 75: ('lgbm', {'n_estimators': 14142, 'num_leaves': 109, 'min_child_samples': 9, 'learning_rate': 0.03738170215583523, 'log_max_bin': 10, 'colsample_bytree': 0.793282520584286, 'reg_alpha': 0.028508654862734066, 'reg_lambda': 0.018825817301132843}, 512.6307168006897)}

# %% [markdown]
# Check the learning curve from the log file

# %%
from flaml.automl.data import get_output_from_log
time_history, best_valid_loss_history, valid_loss_history, config_history, metric_history = get_output_from_log(filename=automl_settings["log_file_name"], time_budget=200)

plt.title("Learning Curve")
plt.xlabel("Wall Clock Time (s)")
plt.ylabel("RMSE [K]")
plt.step(time_history, 1- np.sqrt(np.array(best_valid_loss_history)), where="post")
plt.show()
d = get_output_from_log(filename=automl_settings["log_file_name"], time_budget=500)
display(d)
# Out:
# ([0.6071858406066895,
#   1.3773672580718994,
#   2.1153724193573,
#   2.8765687942504883,
#   4.509388208389282,
#   11.229356288909912,
#   34.97319316864014,
#   79.52716279029846,
#   161.33840680122375,
#   224.26029896736145,
#   306.0122208595276],
#  [1.5456135136096896,
#   1.2797572795574808,
#   0.7938526412101774,
#   0.7235171621939458,
#   0.5625839384564693,
#   0.34815461174667295,
#   0.23516819210347845,
#   0.23153319917349519,
#   0.2247612234514588,
#   0.21042838497241872,
#   0.20198757362796163],
#  [1.5456135136096896,
#   1.2797572795574808,
#   0.7938526412101774,
#   0.7235171621939458,
#   0.5625839384564693,
#   0.34815461174667295,
#   0.23516819210347845,
#   0.23153319917349519,
#   0.2247612234514588,
#   0.21042838497241872,
#   0.20198757362796163],
#  [{'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 4,
#     'num_leaves': 4,
#     'min_child_samples': 20,
#     'learning_rate': 0.09999999999999995,
#     'log_max_bin': 8,
#     'colsample_bytree': 1.0,
#     'reg_alpha': 0.0009765625,
#     'reg_lambda': 1.0},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 4,
#     'num_leaves': 4,
#     'min_child_samples': 20,
#     'learning_rate': 0.09999999999999995,
#     'log_max_bin': 8,
#     'colsample_bytree': 1.0,
#     'reg_alpha': 0.0009765625,
#     'reg_lambda': 1.0}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 4,
#     'num_leaves': 4,
#     'min_child_samples': 12,
#     'learning_rate': 0.26770501231052046,
#     'log_max_bin': 7,
#     'colsample_bytree': 1.0,
#     'reg_alpha': 0.001348364934537134,
#     'reg_lambda': 1.4442580148221913},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 4,
#     'num_leaves': 4,
#     'min_child_samples': 12,
#     'learning_rate': 0.26770501231052046,
#     'log_max_bin': 7,
#     'colsample_bytree': 1.0,
#     'reg_alpha': 0.001348364934537134,
#     'reg_lambda': 1.4442580148221913}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 12,
#     'num_leaves': 4,
#     'min_child_samples': 9,
#     'learning_rate': 0.7260594590615893,
#     'log_max_bin': 9,
#     'colsample_bytree': 0.9285002286474459,
#     'reg_alpha': 0.0036840681931986645,
#     'reg_lambda': 0.7532480505730402},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 12,
#     'num_leaves': 4,
#     'min_child_samples': 9,
#     'learning_rate': 0.7260594590615893,
#     'log_max_bin': 9,
#     'colsample_bytree': 0.9285002286474459,
#     'reg_alpha': 0.0036840681931986645,
#     'reg_lambda': 0.7532480505730402}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 14,
#     'num_leaves': 5,
#     'min_child_samples': 5,
#     'learning_rate': 0.7590459488450945,
#     'log_max_bin': 8,
#     'colsample_bytree': 0.8304072431299575,
#     'reg_alpha': 0.001951378031519758,
#     'reg_lambda': 0.04792552866398477},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 14,
#     'num_leaves': 5,
#     'min_child_samples': 5,
#     'learning_rate': 0.7590459488450945,
#     'log_max_bin': 8,
#     'colsample_bytree': 0.8304072431299575,
#     'reg_alpha': 0.001951378031519758,
#     'reg_lambda': 0.04792552866398477}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 53,
#     'num_leaves': 4,
#     'min_child_samples': 4,
#     'learning_rate': 0.41929025492645006,
#     'log_max_bin': 8,
#     'colsample_bytree': 0.7610534336273627,
#     'reg_alpha': 0.0009765625,
#     'reg_lambda': 0.009280655005879927},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 53,
#     'num_leaves': 4,
#     'min_child_samples': 4,
#     'learning_rate': 0.41929025492645006,
#     'log_max_bin': 8,
#     'colsample_bytree': 0.7610534336273627,
#     'reg_alpha': 0.0009765625,
#     'reg_lambda': 0.009280655005879927}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 189,
#     'num_leaves': 20,
#     'min_child_samples': 3,
#     'learning_rate': 0.17402065726724145,
#     'log_max_bin': 8,
#     'colsample_bytree': 0.6649148062238498,
#     'reg_alpha': 0.0009765625,
#     'reg_lambda': 0.006761362450996487},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 189,
#     'num_leaves': 20,
#     'min_child_samples': 3,
#     'learning_rate': 0.17402065726724145,
#     'log_max_bin': 8,
#     'colsample_bytree': 0.6649148062238498,
#     'reg_alpha': 0.0009765625,
#     'reg_lambda': 0.006761362450996487}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 109,
#     'num_leaves': 84,
#     'min_child_samples': 2,
#     'learning_rate': 0.1530612501227463,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.7463308378914483,
#     'reg_alpha': 0.0009765625,
#     'reg_lambda': 0.012698515198279517},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 109,
#     'num_leaves': 84,
#     'min_child_samples': 2,
#     'learning_rate': 0.1530612501227463,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.7463308378914483,
#     'reg_alpha': 0.0009765625,
#     'reg_lambda': 0.012698515198279517}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 218,
#     'num_leaves': 39,
#     'min_child_samples': 2,
#     'learning_rate': 0.18908812295671118,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.7965188503204359,
#     'reg_alpha': 0.004577823970660193,
#     'reg_lambda': 0.02722880765786953},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 218,
#     'num_leaves': 39,
#     'min_child_samples': 2,
#     'learning_rate': 0.18908812295671118,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.7965188503204359,
#     'reg_alpha': 0.004577823970660193,
#     'reg_lambda': 0.02722880765786953}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 558,
#     'num_leaves': 17,
#     'min_child_samples': 4,
#     'learning_rate': 0.1591234985903699,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.8550732733223378,
#     'reg_alpha': 0.036114468962103394,
#     'reg_lambda': 0.028209651407471815},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 558,
#     'num_leaves': 17,
#     'min_child_samples': 4,
#     'learning_rate': 0.1591234985903699,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.8550732733223378,
#     'reg_alpha': 0.036114468962103394,
#     'reg_lambda': 0.028209651407471815}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 1228,
#     'num_leaves': 15,
#     'min_child_samples': 7,
#     'learning_rate': 0.08108481044463384,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.838019535354181,
#     'reg_alpha': 0.003941416412231428,
#     'reg_lambda': 0.10554687066068354},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 1228,
#     'num_leaves': 15,
#     'min_child_samples': 7,
#     'learning_rate': 0.08108481044463384,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.838019535354181,
#     'reg_alpha': 0.003941416412231428,
#     'reg_lambda': 0.10554687066068354}},
#   {'Current Learner': 'lgbm',
#    'Current Sample': 80000,
#    'Current Hyper-parameters': {'n_estimators': 3105,
#     'num_leaves': 81,
#     'min_child_samples': 7,
#     'learning_rate': 0.09923336893317476,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.7750396473588606,
#     'reg_alpha': 0.014094603319861362,
#     'reg_lambda': 0.026152243630780125},
#    'Best Learner': 'lgbm',
#    'Best Hyper-parameters': {'n_estimators': 3105,
#     'num_leaves': 81,
#     'min_child_samples': 7,
#     'learning_rate': 0.09923336893317476,
#     'log_max_bin': 10,
#     'colsample_bytree': 0.7750396473588606,
#     'reg_alpha': 0.014094603319861362,
#     'reg_lambda': 0.026152243630780125}}],
#  [{'pred_time': 3.793805837631226e-07},
#   {'pred_time': 1.2419819831848144e-07},
#   {'pred_time': 1.661628484725952e-07},
#   {'pred_time': 1.5411078929901123e-07},
#   {'pred_time': 4.3762624263763434e-07},
#   {'pred_time': 6.511628627777099e-07},
#   {'pred_time': 7.462114095687866e-07},
#   {'pred_time': 1.1720985174179078e-06},
#   {'pred_time': 4.12430465221405e-06},
#   {'pred_time': 6.196752190589904e-06},
#   {'pred_time': 6.468695402145385e-05}])

# %%
# =============load model================
automl = pickle.load(open('ERP_automl_model_TSAmax.pkl', 'rb'))

# %%
# evaluate the final model performance
y_test = test[label]
y_pred_test = automl.predict(test[feature_ls])
print("testing rmse:", mean_squared_error(y_true=y_test, y_pred=y_pred_test, squared=False))
print("testing r2:", r2_score(y_true=y_test, y_pred=y_pred_test))
print("testing mae:", mean_absolute_error(y_true = y_test, y_pred = y_pred_test))
# Out:
# testing rmse: 0.15994510463719633
# testing r2: 0.9919357074965658
# testing mae: 0.06507014953159702
# d:\python_Anaconda_install\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
### 将y_test_real写成nc格式文件
# import xarray as xr
# display(y_pred_test.shape)
# ds_test_klaml = xr.Dataset(
#     {
#         "y_pred": (("200000"), y_pred_test)
#     },
# )
# ds_test_klaml.to_netcdf("ERP_ds_test_klaml.nc")# 
# print("NetCDF 文件保存成功！")

# %%
### example plotting

residuals_train = train[label] - y_pred_train
residuals_test = test[label] - y_pred_test

plt.figure(figsize=(12, 6))
sns.histplot(residuals_train, kde=True, color='blue', label='train')# , binwidth = 0.1
sns.histplot(residuals_test, kde=True, color='red', label='test')

mean_train = residuals_train.mean()
mean_test = residuals_test.mean()

plt.axvline(mean_train, color='blue', linestyle='dashed', linewidth=1)
plt.axvline(mean_test, color='red', linestyle='dashed', linewidth=1)

plt.text(-5, 200, f'Mean residuals: {mean_train.round(2)} [K]', rotation=0, color='blue')
plt.text(-5, 100, f'Mean residuals: {mean_test.round(2)} [K]', rotation=0, color='red')

plt.ylabel('Frequency')
plt.xlabel('Residual [K]')
plt.title('Residual distribution')
plt.legend()
plt.show()

# %% [markdown]
# ### Feature Importance

# %%
# =========== feature importance =========== 

# only when the model is tree-based, we can get the feature importance directly from the model
fi = automl.model.estimator.feature_importances_
display(fi)
# 排序
# 把重要性和特征名放到DataFrame中
df_fi = pd.DataFrame({'feature': feature_ls, 'importance': fi})
# 按importance降序排序
df_fi = df_fi.sort_values(by='importance', ascending=False)

# plot
plt.figure(figsize=(10, 5))
sns.barplot(x='importance', y='feature', data=df_fi)
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance")
plt.show()

# %% [markdown]
# ### Using Shap for Feature IMportance

# %%
## SHAPELY importances
# !pip install shap==0.39.0
# =========== shapley ===========
import shap

# %%
# explain the model's predictions using SHAP
explainer = shap.Explainer(automl.model.estimator)
shap_values_klaml = explainer(test[feature_ls])
shap.summary_plot(shap_values_klaml, plot_type='bar')
# visualize the training set predictions
shap.plots.beeswarm(shap_values_klaml)
print(shap_values_klaml)

# %%
# visualize the first prediction's explanation
shap.initjs() # shap.initjs() 负责在Jupyter Notebook等环境初始化JavaScript支持，用于后续的交互式图形显示
shap.plots.waterfall(shap_values_klaml[1007])
